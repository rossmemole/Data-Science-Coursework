# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# Import the required Python libraries 

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os
import requests
import sqlalchemy
from sqlalchemy import create_engine

# %%
# Connect to SQL database using 'create_engine' with SQLAlchemy

conn_string_business = 'mysql://{user}:{password}@{host}:{port}/{db}?charset=utf8'.format(
    user='notebook', 
    password='notebook', 
    host = 'dreamteam.conr4khphv8c.us-east-2.rds.amazonaws.com', 
    port=3306, 
    db='nyhealth',
    encoding = 'utf-8'
)

engine = create_engine(conn_string_business)

# %%
# Sebastian, Ross, and Ethan created API keys at https://www.yelp.com/developers/ - All keys listed below
# This is a test request to make sure the data Yelp returns is sufficient

rosskey = 'yJnJ8IxCWjMYXqoomIg2ySfDoHSSwpa5dcMzgKe7YNgYfzeF8jA049dzxDd6-EHZqATK2n07KS8ZOML_dbPqpceAA1WGoPpzzrnz_AnMOgFikw4XFVfcoHZabzYpW3Yx'
auth_header = {'Authorization': 'Bearer ' + rosskey}

# For Yelp API Documentation, see https://www.yelp.com/developers/documentation/v3
# We're use the URL below to search by phone number

url = 'https://api.yelp.com/v3/businesses/search/phone'

# By simply passing the restaurant phone number with a "+1" we get a response

parameters = {
    "phone": "+12128658777"
}

# Issue the authenticated request

resp = requests.get(url, headers=auth_header, params=parameters)
testdata = resp.json()

# %%
# The response contains three keys
# The main response is the "business", which contains a list of the results
testdata.keys()
# Out:
# dict_keys(['businesses', 'total'])

# %%
testdata
# Out:
# {'businesses': [{'alias': 'jimbos-hamburger-palace-new-york-10',
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 40.8135833740234,
#     'longitude': -73.9558029174805},
#    'display_phone': '(212) 865-8777',
#    'id': 'Rx3m7vtf-eWBSQ4AavQl8g',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/b0gAXXUeO8-v70fRCx0nDg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1345 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['1345 Amsterdam Ave', 'New York, NY 10027'],
#     'state': 'NY',
#     'zip_code': '10027'},
#    'name': "Jimbo's Hamburger Palace",
#    'phone': '+12128658777',
#    'price': '$',
#    'rating': 4.0,
#    'review_count': 16,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/jimbos-hamburger-palace-new-york-10?adjust_creative=11VDKWSHlwVqVDIBUer9Kw&utm_campaign=yelp_api_v3&utm_medium=api_v3_phone_search&utm_source=11VDKWSHlwVqVDIBUer9Kw'}],
#  'total': 1}

# %%
# We can put the results directly into a dataframe
# The issue is that some columns (e.g location) are composite and
# instead of containing values, the cells contain *dictionaries*
# Panos showed us how to use assorted Pandas methods to clean this up.
df = pd.DataFrame(testdata['businesses'])

# We take the dictionaries in the location and coordinates columns
# and create new dataframes for both of them, with each element of the dictionary
# now being a column
address_df = df.location.apply(pd.Series)
coordinates_df = df.coordinates.apply(pd.Series)

# We remove what we don't need from the original dataframe
df.drop('location', axis='columns', inplace=True)
df.drop('coordinates', axis='columns', inplace=True)
df.drop('url', axis='columns', inplace=True)
df.drop('display_phone', axis='columns', inplace=True)
df.drop('alias', axis='columns', inplace=True)
df.drop('categories', axis='columns', inplace=True)
df.drop('transactions', axis='columns', inplace=True)
df.drop('image_url', axis='columns', inplace=True)

# Put together the original dataframe, the addresses, and the coordinates dataframes
# (We concatenates the 3 dataframes bu putting them all next to each other)
new_df = pd.concat([df, address_df, coordinates_df], axis='columns')
new_df
# Out:
#                        id  is_closed                      name         phone  \
# 0  Rx3m7vtf-eWBSQ4AavQl8g      False  Jimbo's Hamburger Palace  +12128658777
#
#   price  rating  review_count            address1 address2 address3      city  \
# 0     $     4.0            16  1345 Amsterdam Ave                    New York
#
#   zip_code country state                           display_address   latitude  \
# 0    10027      US    NY  [1345 Amsterdam Ave, New York, NY 10027]  40.813583
#
#    longitude
# 0 -73.955803

# %%
# Must CONCAT +1 FOR nyhealth PHONE numbers to send Yelp the right request

query = '''
select distinct CONCAT("+1", phone) as phone
from NYHEALTH
where BORO = 'MANHATTAN'
;
'''
phone_numbers = pd.read_sql(query, con=engine)

# %%
phone_numbers
# Out:
#              phone
# 0     +12127521495
# 1     +19172620380
# 2     +12122576434
# 3     +16469129061
# 4     +12129410911
# 5     +12126775834
# 6     +16468613403
# 7     +12122475756
# 8     +12127772188
# 9     +12128658777
# 10    +12128580511
# 11    +12127535959
# 12    +12127854700
# 13    +12123692180
# 14    +12126885373
# 15    +12126159700
# 16    +12127550123
# 17    +12125660006
# 18    +12129950242
# 19    +12127585555
# 20    +12122898226
# 21    +12122228300
# 22    +16469228564
# 23    +12122280228
# 24    +12123486222
# 25    +12124265800
# 26    +12127363206
# 27    +12128748840
# 28    +12129477325
# 29    +12127328988
# ...            ...
# 9906  +15626677851
# 9907  +16092042068
# 9908  +16465123076
# 9909  +16463464153
# 9910  +13477636995
# 9911  +16464764549
# 9912  +19175237656
# 9913  +19292535400
# 9914  +17147230484
# 9915  +16468586236
# 9916  +12128679523
# 9917  +18609333511
# 9918  +12129661378
# 9919  +12125828806
# 9920  +12125108610
# 9921  +19174823887
# 9922  +12126440440
# 9923  +19177333937
# 9924  +16465499378
# 9925  +12122561002
# 9926  +17189542635
# 9927  +12126755096
# 9928  +13474203372
# 9929  +16462214684
# 9930  +12126894002
# 9931  +13472551437
# 9932  +19176567839
# 9933  +12123623333
# 9934  +19172508405
# 9935  +12127775314
#
# [9936 rows x 1 columns]

# %%
# DO NOT RUN UNLESS YOU CHANGE THE SUBSECT OTHERWISE WILL CREATE OVER 9000 JSON FILES

sebastiankey = 'mh0lIHxmIVO9hFI0G3bexfV5h-1WLHNqze9Vb14SZaLM4diYfD5NgPR0-noXYkTZAFUyci1F5OYaCTNr68cIZWFINX3JZh4_GVucrLGaawHHbmQZkQiYVdibIL0mW3Yx'
rosskey = 'yJnJ8IxCWjMYXqoomIg2ySfDoHSSwpa5dcMzgKe7YNgYfzeF8jA049dzxDd6-EHZqATK2n07KS8ZOML_dbPqpceAA1WGoPpzzrnz_AnMOgFikw4XFVfcoHZabzYpW3Yx'
ethankey = '57qiAnSnRWl08a84pPm-ftJqb_WseqUphYrxLqOUxURXGYfHkU3WqDVr10_1ppi2G4wXyLGgR6RKIZklEOJpiSjgNWhJJXNuZWZhA_dH6083WJDOS2UH2n9DpDUpW3Yx'

auth_header = {'Authorization': 'Bearer ' + sebastiankey}
url = 'https://api.yelp.com/v3/businesses/search/phone'
i=0
for i in range(len(phone_numbers)):
    parameter = {'phone': str(phone_numbers['phone'][i])}
    resp = requests.get(url, headers=auth_header, params=parameter)
    data = resp.json()
    n = str(i)+'.json'
    f = open(n, "w")
    json.dump(data, f)
    i+1
    
    if i == 4990:
        break

# Duplicating the function above to run again with a different API key.
# Yelp has a daily limit of 5000 API requests. To download all of the files we need in one day, need two keys.        

auth_header = {'Authorization': 'Bearer ' + ethankey}
url = 'https://api.yelp.com/v3/businesses/search/phone'
i=4990
for i in range(i, len(phone_numbers)):
    parameter = {'phone': str(phone_numbers['phone'][i])}
    resp = requests.get(url, headers=auth_header, params=parameter)
    data = resp.json()
    n = str(i)+'.json'
    f = open(n, "w")
    json.dump(data, f)
    i+1
    
    if i == 9937:
        break

# %%
# Testing loop above with 10 phone numbers

ten_test = phone_numbers.head(10)

# %%
# Testing loop above with 10 phone numbers, remember, arrays start at 0!

ten_test
# Out:
#           phone
# 0  +12127521495
# 1  +19172620380
# 2  +12122576434
# 3  +16469129061
# 4  +12129410911
# 5  +12126775834
# 6  +16468613403
# 7  +12122475756
# 8  +12127772188
# 9  +12128658777

# %%
# Put JSON files into a single DataFrame and append each file to the end of the frame
# Deletes the JSON file once it has been processed

i=0
for i in range(len(phone_numbers)):
    data = json.load(open(str(i)+".json"))
    if i == 0:
        appended = pd.DataFrame(data['businesses'])
        os.remove(str(i)+".json")
        i+1
    else:
        appended = pd.DataFrame(data['businesses']).append(appended, sort=False)
        os.remove(str(i)+".json")
        i+1

# %%
# Final DataFrame with all JSON Files

appended
# Out:
#                                             alias  \
# 0                bleecker-heights-tavern-new-york
# 1                             the-garret-new-york
# 0                       voyager-espresso-new-york
# 1                             amanzi-tea-new-york
# 0                          fu-on-kitchen-new-york
# 0                             cafe-water-new-york
# 0                                 b-side-new-york
# 0                             sanatorium-new-york
# 0                       sushi-on-jones-new-york-3
# 0                   ashoka-on-2nd-avenue-new-york
# 0                      spring-and-varick-new-york
# 1           quattro-gastronomia-italiana-new-york
# 0              szechuan-mountain-house-new-york-2
# 0                  the-standard-ice-rink-new-york
# 1                 the-standard-high-line-new-york
# 0                              sushi-noz-new-york
# 0                     fashion-restaurant-new-york
# 1        riu-plaza-new-york-times-square-new-york
# 0                              wing-club-new-york
# 0                     pressed-juicery-new-york-16
# 0                              republica-new-york
# 0                               scampi-new-york-2
# 0                  rockys-pizza-vinoteca-new-york
# 0                the-boogie-down-grind-café-bronx
# 0                    papa-johns-pizza-new-york-37
# 0                 zeytin-mediterranean-new-york-3
# 0             fuel-grill-and-juice-bar-new-york-6
# 0                          starbucks-new-york-417
# 1                          starbucks-new-york-489
# 0            norma-gastronomia-siciliana-new-york
# ..                                            ...
# 0                     shanghai-cuisine-new-york-6
# 0                    manganaros-hero-boy-new-york
# 0                          emerald-inn-new-york-2
# 1                            emerald-inn-new-york
# 0                            pio-pio-3-new-york-5
# 0                             libertador-new-york
# 0                          remote-lounge-new-york
# 1                        bowery-electric-new-york
# 0                          chicken-ranch-new-york
# 0                           harlem-shake-new-york
# 0                              taco-taco-new-york
# 1                                 mole-new-york-6
# 0                spreads-sandwich-shop-new-york-2
# 0                              barbounia-new-york
# 0                                charlys-new-york
# 0                         korean-express-new-york
# 1                  helens-korean-kitchen-new-york
# 0                                 cafe-k-new-york
# 0                     barnes-and-noble-new-york-2
# 0                            leos-bagels-new-york
# 0                         59e59-theaters-new-york
# 1                            threesome-new-york-2
# 0                               polpette-new-york
# 0             jimbos-hamburger-palace-new-york-10
# 0                              gen-sushi-new-york
# 0                    la-colombe-coffee-new-york-4
# 0                         golden-unicorn-new-york
# 0                        the-black-derby-new-york
# 0   birdbath-neighborhood-green-bakery-new-york-7
# 0                          la-grenouille-new-york
#
#                                            categories  \
# 0   [{'alias': 'sportsbars', 'title': 'Sports Bars'}]
# 1   [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 0   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 1      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 0   [{'alias': 'restaurants', 'title': 'Restaurant...
# 0   [{'alias': 'delis', 'title': 'Delis'}, {'alias...
# 0       [{'alias': 'divebars', 'title': 'Dive Bars'}]
# 0   [{'alias': 'cocktailbars', 'title': 'Cocktail ...
# 0   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...
# 0            [{'alias': 'indpak', 'title': 'Indian'}]
# 0   [{'alias': 'newamerican', 'title': 'American (...
# 1          [{'alias': 'italian', 'title': 'Italian'}]
# 0        [{'alias': 'szechuan', 'title': 'Szechuan'}]
# 0   [{'alias': 'skatingrinks', 'title': 'Skating R...
# 1   [{'alias': 'hotels', 'title': 'Hotels'}, {'ali...
# 0   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...
# 0   [{'alias': 'newamerican', 'title': 'American (...
# 1            [{'alias': 'hotels', 'title': 'Hotels'}]
# 0   [{'alias': 'korean', 'title': 'Korean'}, {'ali...
# 0   [{'alias': 'juicebars', 'title': 'Juice Bars &...
# 0   [{'alias': 'lounges', 'title': 'Lounges'}, {'a...
# 0   [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 0   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...
# 0   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 0              [{'alias': 'pizza', 'title': 'Pizza'}]
# 0   [{'alias': 'mediterranean', 'title': 'Mediterr...
# 0   [{'alias': 'juicebars', 'title': 'Juice Bars &...
# 0      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 1      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 0   [{'alias': 'italian', 'title': 'Italian'}, {'a...
# ..                                                ...
# 0        [{'alias': 'szechuan', 'title': 'Szechuan'}]
# 0   [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# 0   [{'alias': 'divebars', 'title': 'Dive Bars'}, ...
# 1   [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 0   [{'alias': 'latin', 'title': 'Latin American'}...
# 0   [{'alias': 'argentine', 'title': 'Argentine'},...
# 0          [{'alias': 'lounges', 'title': 'Lounges'}]
# 1   [{'alias': 'lounges', 'title': 'Lounges'}, {'a...
# 0   [{'alias': 'spanish', 'title': 'Spanish'}, {'a...
# 0   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...
# 0          [{'alias': 'mexican', 'title': 'Mexican'}]
# 1          [{'alias': 'mexican', 'title': 'Mexican'}]
# 0   [{'alias': 'sandwiches', 'title': 'Sandwiches'...
# 0   [{'alias': 'greek', 'title': 'Greek'}, {'alias...
# 0   [{'alias': 'diners', 'title': 'Diners'}, {'ali...
# 0            [{'alias': 'korean', 'title': 'Korean'}]
# 1            [{'alias': 'korean', 'title': 'Korean'}]
# 0   [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 0   [{'alias': 'mags', 'title': 'Newspapers & Maga...
# 0   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...
# 0   [{'alias': 'theater', 'title': 'Performing Art...
# 1   [{'alias': 'theater', 'title': 'Performing Art...
# 0   [{'alias': 'italian', 'title': 'Italian'}, {'a...
# 0   [{'alias': 'burgers', 'title': 'Burgers'}, {'a...
# 0   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...
# 0      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]
# 0   [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'al...
# 0   [{'alias': 'newamerican', 'title': 'American (...
# 0        [{'alias': 'bakeries', 'title': 'Bakeries'}]
# 0   [{'alias': 'french', 'title': 'French'}, {'ali...
#
#                                           coordinates   display_phone  \
# 0   {'latitude': 40.7323112487793, 'longitude': -7...  (212) 675-6157
# 1    {'latitude': 40.73238, 'longitude': -74.0038457}  (212) 675-6157
# 0    {'latitude': 40.708897, 'longitude': -74.006676}  (212) 227-2744
# 1   {'latitude': 40.7159805, 'longitude': -74.0105...  (212) 227-2744
# 0      {'latitude': 40.81914, 'longitude': -73.94038}  (212) 862-5660
# 0   {'latitude': 40.7056344, 'longitude': -74.0068...  (212) 785-1320
# 0    {'latitude': 40.728454, 'longitude': -73.978988}  (212) 475-4600
# 0    {'latitude': 40.721057, 'longitude': -73.980773}  (212) 614-0300
# 0   {'latitude': 40.7338884211791, 'longitude': -7...  (646) 357-0453
# 0   {'latitude': 40.7798555, 'longitude': -73.9500...  (212) 876-9100
# 0      {'latitude': 40.72549, 'longitude': -74.00529}  (212) 842-4500
# 1      {'latitude': 40.72554, 'longitude': -74.00542}  (212) 842-4500
# 0      {'latitude': 40.72911, 'longitude': -73.98858}  (917) 388-3866
# 0   {'latitude': 40.7406998, 'longitude': -74.0078...  (212) 645-4646
# 1    {'latitude': 40.740829, 'longitude': -74.008071}  (212) 645-4646
# 0      {'latitude': 40.77385, 'longitude': -73.95813}  (917) 338-1792
# 0       {'latitude': 40.7601, 'longitude': -73.98838}  (646) 864-1100
# 1    {'latitude': 40.759942, 'longitude': -73.988074}  (646) 864-1100
# 0   {'latitude': 40.7408498, 'longitude': -74.0046...  (917) 915-0674
# 0   {'latitude': 40.7067184448242, 'longitude': -7...  (646) 998-4981
# 0      {'latitude': 40.86375, 'longitude': -73.92635}  (646) 895-9444
# 0      {'latitude': 40.73902, 'longitude': -73.99358}  (212) 888-2171
# 0      {'latitude': 40.74658, 'longitude': -73.97704}  (646) 678-3978
# 0      {'latitude': 40.81843, 'longitude': -73.88865}  (718) 874-7313
# 0   {'latitude': 40.79898878932, 'longitude': -73....  (212) 864-7272
# 0      {'latitude': 40.70874, 'longitude': -74.00714}  (212) 227-1908
# 0   {'latitude': 40.7414207, 'longitude': -73.9809...  (212) 684-2221
# 0    {'latitude': 40.711179, 'longitude': -74.015261}  (212) 587-9512
# 1    {'latitude': 40.710837, 'longitude': -74.015412}  (212) 587-9512
# 0    {'latitude': 40.743553, 'longitude': -73.980026}  (212) 889-0600
# ..                                                ...             ...
# 0   {'latitude': 40.715768, 'longitude': -73.9992981}  (212) 732-8988
# 0   {'latitude': 40.7556311, 'longitude': -73.9944...  (212) 947-7325
# 0       {'latitude': 40.7792, 'longitude': -73.98381}  (212) 874-8840
# 1   {'latitude': 40.775665640831, 'longitude': -73...  (212) 874-8840
# 0        {'latitude': 40.77959, 'longitude': -73.947}  (212) 426-5800
# 0      {'latitude': 40.77998, 'longitude': -73.95043}  (212) 348-6222
# 0      {'latitude': 40.7257, 'longitude': -73.991676}  (212) 228-0228
# 1      {'latitude': 40.72576, 'longitude': -73.99179}  (212) 228-0228
# 0       {'latitude': 40.84839, 'longitude': -73.9324}  (646) 922-8564
# 0   {'latitude': 40.8070988060148, 'longitude': -7...  (212) 222-8300
# 0   {'latitude': 40.7800979614258, 'longitude': -7...  (212) 289-8226
# 1    {'latitude': 40.780331, 'longitude': -73.950302}  (212) 289-8226
# 0   {'latitude': 40.7443984597921, 'longitude': -7...  (212) 758-5555
# 0       {'latitude': 40.7382, 'longitude': -73.98804}  (212) 995-0242
# 0   {'latitude': 40.7095278340815, 'longitude': -7...  (212) 566-0006
# 0      {'latitude': 40.76423, 'longitude': -73.96654}  (212) 755-0123
# 1   {'latitude': 40.7643038034439, 'longitude': -7...  (212) 755-0123
# 0   {'latitude': 40.756843239069, 'longitude': -73...  (212) 688-5373
# 0      {'latitude': 40.77901, 'longitude': -73.95545}  (212) 369-2180
# 0   {'latitude': 40.7048928861349, 'longitude': -7...  (212) 785-4700
# 0      {'latitude': 40.76329, 'longitude': -73.97046}  (212) 753-5959
# 1   {'latitude': 40.7633536309004, 'longitude': -7...  (212) 753-5959
# 0   {'latitude': 40.7858352585311, 'longitude': -7...  (212) 858-0511
# 0   {'latitude': 40.8135833740234, 'longitude': -7...  (212) 865-8777
# 0    {'latitude': 40.729687, 'longitude': -73.999352}  (212) 777-2188
# 0    {'latitude': 40.728221, 'longitude': -73.993165}  (212) 677-5834
# 0   {'latitude': 40.7136770496642, 'longitude': -7...  (212) 941-0911
# 0     {'latitude': 40.737266, 'longitude': -74.00399}  (646) 912-9061
# 0   {'latitude': 40.7525423, 'longitude': -73.9741...  (212) 257-6434
# 0      {'latitude': 40.75972, 'longitude': -73.97555}  (212) 752-1495
#
#                         id                                          image_url  \
# 0   bgv_tR6ZJjw3js44zvcJUg  https://s3-media1.fl.yelpcdn.com/bphoto/u6X8oi...
# 1   dJoWkpVxWcvdqNRo7w622w  https://s3-media4.fl.yelpcdn.com/bphoto/wvfw7O...
# 0   qzdCvtgpCDjNVV_zRJB5EQ  https://s3-media3.fl.yelpcdn.com/bphoto/f5U1Zl...
# 1   EPJjEMdlsGtEridFDqvSFg  https://s3-media2.fl.yelpcdn.com/bphoto/EhzM8L...
# 0   JAjbYabOKnPaZyKLcNjFAA
# 0   aoYDuvipcT_XGAM5ckFJnA  https://s3-media2.fl.yelpcdn.com/bphoto/TNboxc...
# 0   WvzuSPayCKimxkjWYQHg0Q  https://s3-media1.fl.yelpcdn.com/bphoto/i4j0M0...
# 0   18CzGWvJqc_9xoMpwEgl-w  https://s3-media3.fl.yelpcdn.com/bphoto/o37bfU...
# 0   IS94JDTcq_WedBcj6P4qpQ  https://s3-media2.fl.yelpcdn.com/bphoto/PhY0ZQ...
# 0   jJYQJGygWjIX6_0MiIoJRQ  https://s3-media1.fl.yelpcdn.com/bphoto/g-vL8I...
# 0   RPGhmMXIBEItJpEZnIVzlg  https://s3-media4.fl.yelpcdn.com/bphoto/03sFtA...
# 1   xHHEMDfrysowWC5NbYrL2A  https://s3-media2.fl.yelpcdn.com/bphoto/ce2JXs...
# 0   jc7lVTvmYMIK5RNpENtS6w  https://s3-media4.fl.yelpcdn.com/bphoto/Gz84ka...
# 0       False  {'address1': '210 W 10th St', 'address2': '', ...
# 0       False  {'address1': '1718 2nd Ave', 'address2': None,...
# 0       False  {'address1': '246 Spring St', 'address2': '', ...
# 1        True  {'address1': '246 Spring St', 'address2': '', ...
# 0       False  {'address1': '23 St Marks Pl', 'address2': '',...
# 0       False  {'address1': '848 Washington St', 'address2': ...
# 1       False  {'address1': '848 Washington Street', 'address...
# 0       False  {'address1': '181 E 78th St', 'address2': '', ...
# 0       False  {'address1': '305 W 46th St', 'address2': '', ...
# 1       False  {'address1': '305 W 46th St', 'address2': '', ...
# 0       False  {'address1': '353 W 14th St', 'address2': None...
# 0       False  {'address1': '100 Maiden Ln', 'address2': None...
# 0       False  {'address1': '160 Dyckman St', 'address2': '',...
# 0       False  {'address1': '30 W 18th St', 'address2': '', '...
# 0       False  {'address1': '535 3rd Ave', 'address2': '', 'a...
# 0       False  {'address1': '866B Hunts Point Ave', 'address2...
# 0       False  {'address1': '896 Amsterdam Ave', 'address2': ...
# 0       False  {'address1': '110 William St', 'address2': Non...
# 0       False  {'address1': '379 3rd Ave', 'address2': None, ...
# 0       False  {'address1': '1 World Financial Ctr', 'address...
# 1       False  {'address1': '200 Liberty St', 'address2': 'St...
# 0       False  {'address1': '438 3rd Ave', 'address2': None, ...
# ..        ...                                                ...
# 0       False  {'address1': '89 Bayard St', 'address2': '', '...
# 0       False  {'address1': '494 9th Ave', 'address2': '', 'a...
# 0       False  {'address1': '250 W 72nd St', 'address2': None...
# 1        True  {'address1': '205 Columbus Ave', 'address2': '...
# 0       False  {'address1': '1746 First Ave', 'address2': '',...
# 0       False  {'address1': '1725 2nd Ave', 'address2': '', '...
# 0        True  {'address1': '327 Bowery', 'address2': '', 'ad...
# 1       False  {'address1': '327 Bowery St', 'address2': '', ...
# 0       False  {'address1': '315 Audubon Ave', 'address2': No...
# 0       False  {'address1': '100 W 124th St', 'address2': Non...
# 0        True  {'address1': '1726 2nd Ave', 'address2': '', '...
# 1       False  {'address1': '1735 2nd Ave', 'address2': '', '...
# 0       False  {'address1': '441 Park Ave S', 'address2': '',...
# 0       False  {'address1': '250 Park Ave S', 'address2': '',...
# 0       False  {'address1': '110 Trinity Pl', 'address2': '',...
# 0       False  {'address1': '807 Lexington Ave', 'address2': ...
# 1        True  {'address1': '807 Lexington Ave', 'address2': ...
# 0       False  {'address1': '8 E 48th St', 'address2': None, ...
# 0       False  {'address1': '150 E 86th St', 'address2': '', ...
# 0       False  {'address1': '3 Hanover Sq', 'address2': '', '...
# 0       False  {'address1': '59 E 59th St', 'address2': '', '...
# 1       False  {'address1': '59 E 59th St', 'address2': '', '...
# 0       False  {'address1': '483 Amsterdam Ave', 'address2': ...
# 0       False  {'address1': '1345 Amsterdam Ave', 'address2':...
# 0        True  {'address1': '231 Sullivan St', 'address2': ''...
# 0       False  {'address1': '400 Lafayette St', 'address2': '...
# 0       False  {'address1': '18 E Broadway', 'address2': '', ...
# 0       False  {'address1': '310 W 4th St', 'address2': None,...
# 0       False  {'address1': '140 E 45th St', 'address2': '', ...
# 0       False  {'address1': '3 E 52nd St', 'address2': '', 'a...
#
#                                   name         phone price  rating  \
# 0              Bleecker Heights Tavern  +12126756157    $$     3.5
# 1                           The Garret  +12126756157    $$     3.5
# 0                     Voyager Espresso  +12122272744     $     5.0
# 1                           Amanzi Tea  +12122272744     $     4.0
# 0                        Fu On Kitchen  +12128625660   NaN     3.0
# 0                           Cafe Water  +12127851320    $$     3.0
# 0                               B Side  +12124754600     $     4.0
# 0                           Sanatorium  +12126140300   $$$     3.5
# 0                       Sushi on Jones  +16463570453   $$$     4.0
# 0                 Ashoka on 2nd Avenue  +12128769100    $$     5.0
# 0                      Spring & Varick  +12128424500   NaN     3.5
# 1         Quattro Gastronomia Italiana  +12128424500   $$$     3.0
# 0              Szechuan Mountain House  +19173883866    $$     4.0
# 0                The Standard Ice Rink  +12126454646   NaN     4.0
# 1             The Standard, High Line   +12126454646   $$$     3.0
# 0                            Sushi Noz  +19173381792   NaN     5.0
# 0                   Fashion Restaurant  +16468641100    $$     3.5
# 1      Riu Plaza New York Times Square  +16468641100   $$$     2.5
# 0                            Wing Club  +19179150674   NaN     4.0
# 0                      Pressed Juicery  +16469984981     $     4.0
# 0                            Republica  +16468959444    $$     2.5
# 0                               Scampi  +12128882171   $$$     4.0
# 0               Rocky's Pizza Vinoteca  +16466783978   NaN     3.5
# 0           The Boogie Down Grind Café  +17188747313    $$     4.5
# 0                    Papa John's Pizza  +12128647272    $$     2.5
# 0                 Zeytin Mediterranean  +12122271908   NaN     4.5
# 0               Fuel Grill & Juice Bar  +12126842221     $     3.0
# 0                            Starbucks  +12125879512     $     3.0
# 1                            Starbucks  +12125879512    $$     3.0
# 0          NORMA Gastronomia Siciliana  +12128890600    $$     4.5
# ..                                 ...           ...   ...     ...
# 0                     Shanghai Cuisine  +12127328988    $$     3.0
# 0                 Manganaro's Hero Boy  +12129477325    $$     3.0
# 0                          Emerald Inn  +12128748840    $$     3.5
# 1                          Emerald Inn  +12128748840    $$     3.5
# 0                            Pio Pio 3  +12124265800    $$     4.0
# 0                           Libertador  +12123486222    $$     3.5
# 0                        Remote Lounge  +12122280228   NaN     3.5
# 1                      Bowery Electric  +12122280228    $$     3.0
# 0                        Chicken Ranch  +16469228564    $$     4.5
# 0                         Harlem Shake  +12122228300    $$     3.5
# 0                            Taco Taco  +12122898226    $$     3.5
# 1                                 Mole  +12122898226    $$     3.0
# 0                Spreads Sandwich Shop  +12127585555    $$     3.5
# 0                            Barbounia  +12129950242   $$$     3.5
# 0                              Charlys  +12125660006     $     3.5
# 0                       Korean Express  +12127550123    $$     3.5
# 1               Helen's Korean Kitchen  +12127550123     $     3.0
# 0                               Cafe K  +12126885373    $$     3.0
# 0                       Barnes & Noble  +12123692180    $$     4.0
# 0                         Leo's Bagels  +12127854700     $     3.5
# 0                       59E59 Theaters  +12127535959   NaN     4.5
# 1                            Threesome  +12127535959   NaN     4.0
# 0                             Polpette  +12128580511    $$     4.0
# 0             Jimbo's Hamburger Palace  +12128658777     $     4.0
# 0                            Gen Sushi  +12127772188    $$     4.0
# 0                    La Colombe Coffee  +12126775834    $$     4.5
# 0                       Golden Unicorn  +12129410911    $$     3.5
# 0                      The Black Derby  +16469129061    $$     4.5
# 0   Birdbath Neighborhood Green Bakery  +12122576434    $$     4.0
# 0                        La Grenouille  +12127521495  $$$$     4.0
#
#     review_count                                transactions  \
# 0             58                                          []
# 1            195                                          []
# 0             87                                          []
# 1              9                                          []
# 0              2                                          []
# 0             68                          [delivery, pickup]
# 0             90                                          []
# 0             29                                          []
# 0             78                                          []
# 0             21  [restaurant_reservation, pickup, delivery]
# 0              8                                          []
# 1             36                                          []
# 0            117                                          []
# 0              7                                          []
# 1            500                                          []
# 0             18                                          []
# 0             10                                          []
# 1             87                                          []
# 0              6                          [delivery, pickup]
# 0             26                          [delivery, pickup]
# 0             97                                          []
# 0             76                                          []
# 0             33                          [pickup, delivery]
# 0             21                                          []
# 0              8                          [delivery, pickup]
# 0             20                          [pickup, delivery]
# 0             78                          [delivery, pickup]
# 0             18                                          []
# 1             17                                          []
# 0            173                          [delivery, pickup]
# ..           ...                                         ...
# 0            315                          [delivery, pickup]
# 0            160                          [delivery, pickup]
# 0             65                                          []
# 1             48                                          []
# 0            696                                          []
# 0            382                                          []
# 0             12                                          []
# 1            229                                          []
# 0             46                          [pickup, delivery]
# 0            782                          [delivery, pickup]
# 0            185                                          []
# 1            315                          [delivery, pickup]
# 0            136                          [pickup, delivery]
# 0           1063                                          []
# 0            126                          [pickup, delivery]
# 0            252                          [delivery, pickup]
# 1             44                          [delivery, pickup]
# 0             55                          [delivery, pickup]
# 0            164                                          []
# 0            662                          [delivery, pickup]
# 0             34                                          []
# 1              4                                          []
# 0            204                          [pickup, delivery]
# 0             16                                          []
# 0              6                                          []
# 0            520                                          []
# 0           1472                                          []
# 0             93                                          []
# 0             58                                          []
# 0            362                                          []
#
#                                                   url
# 0   https://www.yelp.com/biz/bleecker-heights-tave...
# 1   https://www.yelp.com/biz/the-garret-new-york?a...
# 0   https://www.yelp.com/biz/voyager-espresso-new-...
# 1   https://www.yelp.com/biz/amanzi-tea-new-york?a...
# 0   https://www.yelp.com/biz/fu-on-kitchen-new-yor...
# 0   https://www.yelp.com/biz/cafe-water-new-york?a...
# 0   https://www.yelp.com/biz/b-side-new-york?adjus...
# 0   https://www.yelp.com/biz/sanatorium-new-york?a...
# 0   https://www.yelp.com/biz/sushi-on-jones-new-yo...
# 0   https://www.yelp.com/biz/ashoka-on-2nd-avenue-...
# 0   https://www.yelp.com/biz/spring-and-varick-new...
# 1   https://www.yelp.com/biz/quattro-gastronomia-i...
# 0   https://www.yelp.com/biz/szechuan-mountain-hou...
# 0   https://www.yelp.com/biz/the-standard-ice-rink...
# 1   https://www.yelp.com/biz/the-standard-high-lin...
# 0   https://www.yelp.com/biz/sushi-noz-new-york?ad...
appended.drop('display_phone', axis='columns', inplace=True)
appended.drop('alias', axis='columns', inplace=True)
appended.drop('categories', axis='columns', inplace=True)
appended.drop('transactions', axis='columns', inplace=True)
appended.drop('image_url', axis='columns', inplace=True)

final_appended = pd.concat([appended, address_df, coordinates_df], axis='columns')
final_appended
# Out:
#                         id  is_closed                                name  \
# 0   bgv_tR6ZJjw3js44zvcJUg       True             Bleecker Heights Tavern
# 1   dJoWkpVxWcvdqNRo7w622w      False                          The Garret
# 0   qzdCvtgpCDjNVV_zRJB5EQ      False                    Voyager Espresso
# 1   EPJjEMdlsGtEridFDqvSFg       True                          Amanzi Tea
# 0   JAjbYabOKnPaZyKLcNjFAA      False                       Fu On Kitchen
# 0   aoYDuvipcT_XGAM5ckFJnA      False                          Cafe Water
# 0   WvzuSPayCKimxkjWYQHg0Q      False                              B Side
# 0   18CzGWvJqc_9xoMpwEgl-w      False                          Sanatorium
# 0   IS94JDTcq_WedBcj6P4qpQ      False                      Sushi on Jones
# 0   jJYQJGygWjIX6_0MiIoJRQ      False                Ashoka on 2nd Avenue
# 0   RPGhmMXIBEItJpEZnIVzlg      False                     Spring & Varick
# 1   xHHEMDfrysowWC5NbYrL2A       True        Quattro Gastronomia Italiana
# 0   jc7lVTvmYMIK5RNpENtS6w      False             Szechuan Mountain House
# 0   pOFhWvn06kTRqh6xiLE7mA      False               The Standard Ice Rink
# 1   OmgYgPGvf0a8Gz_jWEpLFQ      False            The Standard, High Line
# 0   ocnHpILS80DHL--34L8xpw      False                           Sushi Noz
# 0   gtIfUULNfiwohggcuvjMEA      False                  Fashion Restaurant
# 1   TUWQm_jjmA6gs_wKs-NOrA      False     Riu Plaza New York Times Square
# 0   q5rN0Ygl0Zoq6cyWfcDwvA      False                           Wing Club
# 0   7b2Lezmx-eyuTPoxaGwPmQ      False                     Pressed Juicery
# 0   AH2tDS58NyVBCwd3o8QKRw      False                           Republica
# 0   wOq-Jt26jnFf_rhF4r5D6w      False                              Scampi
# 0   3LNdlijyfwmKyf_KD1MAZg      False              Rocky's Pizza Vinoteca
# 0   YU7U9NPNMwpmGyt_yrCxpA      False          The Boogie Down Grind Café
# 0   l0YbvrhJcgnxIUmuUe7WQQ      False                   Papa John's Pizza
# 0   RvGRsgnHfLXH4q9SWPeaoQ      False                Zeytin Mediterranean
# 0   GaPPKoJC8aSuHrYof04r-g      False              Fuel Grill & Juice Bar
# 0   gfDj7Aa8U9K5UkJ9H65N3w      False                           Starbucks
# 1   TZZsDTd_8Zq1fXqack3X0A      False                           Starbucks
# 0   vVVmHacu2YAxKfpIjhfd1g      False         NORMA Gastronomia Siciliana
# ..                     ...        ...                                 ...
# 0   EF0O_YwVCuWioswtEMrjpg      False                    Shanghai Cuisine
# 0   qZv3GwHh9VHhv9th-N7Wmg      False                Manganaro's Hero Boy
# 0   VD-lSpd2zpWjTR6rUNr1JA      False                         Emerald Inn
# 1   IXMVWBW51z8yazvz764pYQ       True                         Emerald Inn
# 0   jKaR8TTkLBAFmMIsKU786g      False                           Pio Pio 3
# 0   1bjUc14khru1HXuMUe5-5w      False                          Libertador
# 0   Td_zltX3l70mu3RwVZLW-g       True                       Remote Lounge
# 1   4VvcmPvRZF5Oj6OdWJowvg      False                     Bowery Electric
# 0   zQjaTAxYSKpNNj0F4kgjXQ      False                       Chicken Ranch
# 0   opyY8Zk2RqiwLu9SzkQXJA      False                        Harlem Shake
# 0   VqFwAf_8maxd5nCSz9CdrA       True                           Taco Taco
# 1   foAYWheDCF9wUyKPuOGYow      False                                Mole
# 0   CX-QTkLLDz-wkEQ9c-rG6g      False               Spreads Sandwich Shop
# 0   1SaKutXcH38X0KvayyDHUA      False                           Barbounia
# 0   AQBQ_JiVorgEIMhsBwV20A      False                             Charlys
# 0   xSY8MI449l9HvKJKBSlVHA      False                      Korean Express
# 1   nolHhni_TNhq9PybfVKMIA       True              Helen's Korean Kitchen
# 0   jw8Vv4_1hwgU9gaFw9eb-w      False                              Cafe K
# 0   nkqqsaHNmYMa2a2w3wtTqg      False                      Barnes & Noble
# 0   s-Fg5eHqv4VCAn2ANkHiZA      False                        Leo's Bagels
# 0   utzFIRmXy-S_UjuhCx0q3w      False                      59E59 Theaters
# 1   0mrXGnXcCUd8XsTlKoromw      False                           Threesome
# 0   Dpn3cs2D-AfFAGDOTix8og      False                            Polpette
# 0   Rx3m7vtf-eWBSQ4AavQl8g      False            Jimbo's Hamburger Palace
# 0   FtOZ8k5R6v-xHODNeFiUcw       True                           Gen Sushi
# 0   YhOmfXTPu_QRNT3azAu6wA      False                   La Colombe Coffee
# 0   6zM0c7vvoddgza_qvKkATw      False                      Golden Unicorn
# 0   6hw4ibsutVoMl_RK0aAJ7Q      False                     The Black Derby
# 0   KH_2Pm4Cz4yDw5BtTSssCA      False  Birdbath Neighborhood Green Bakery
# 0   KIIYvTOc0Uv90aUHEGvoSg      False                       La Grenouille
#
#            phone price  rating  review_count                  address1  \
# 0   +12126756157    $$     3.5            58           296 Bleecker St
# 1   +12126756157    $$     3.5           195           296 Bleecker St
# 0   +12122272744     $     5.0            87            110 William St
# 1   +12122272744     $     4.0             9           166 Chambers St
# 0   +12128625660   NaN     3.0             2  2419 Adam Clayton Powell
# 0   +12127851320    $$     3.0            68              130 Water St
# 0   +12124754600     $     4.0            90                 204 Ave B
# 0   +12126140300   $$$     3.5            29               14 Avenue C
# 0   +16463570453   $$$     4.0            78             210 W 10th St
# 0   +12128769100    $$     5.0            21              1718 2nd Ave
# 0   +12128424500   NaN     3.5             8             246 Spring St
# 1   +12128424500   $$$     3.0            36             246 Spring St
# 0   +19173883866    $$     4.0           117            23 St Marks Pl
# 0   +12126454646   NaN     4.0             7         848 Washington St
# 1   +12126454646   $$$     3.0           500     848 Washington Street
# 0   +19173381792   NaN     5.0            18             181 E 78th St
# 0   +16468641100    $$     3.5            10             305 W 46th St
# 1   +16468641100   $$$     2.5            87             305 W 46th St
# 0   +19179150674   NaN     4.0             6             353 W 14th St
# 0   +16469984981     $     4.0            26             100 Maiden Ln
# 0   +16468959444    $$     2.5            97            160 Dyckman St
# 0   +12128882171   $$$     4.0            76              30 W 18th St
# 0   +16466783978   NaN     3.5            33               535 3rd Ave
# 0   +17188747313    $$     4.5            21      866B Hunts Point Ave
# 0   +12128647272    $$     2.5             8         896 Amsterdam Ave
# 0   +12122271908   NaN     4.5            20            110 William St
# 0   +12126842221     $     3.0            78               379 3rd Ave
# 0   +12125879512     $     3.0            18     1 World Financial Ctr
# 1   +12125879512    $$     3.0            17            200 Liberty St
# 0   +12128890600    $$     4.5           173               438 3rd Ave
# ..           ...   ...     ...           ...                       ...
# 0   +12127328988    $$     3.0           315              89 Bayard St
# 0   +12129477325    $$     3.0           160               494 9th Ave
# 0   +12128748840    $$     3.5            65             250 W 72nd St
# 1   +12128748840    $$     3.5            48          205 Columbus Ave
# 0   +12124265800    $$     4.0           696            1746 First Ave
# 0   +12123486222    $$     3.5           382              1725 2nd Ave
# 0   +12122280228   NaN     3.5            12                327 Bowery
# 1   +12122280228    $$     3.0           229             327 Bowery St
# 0   +16469228564    $$     4.5            46           315 Audubon Ave
# 0   +12122228300    $$     3.5           782            100 W 124th St
# 0   +12122898226    $$     3.5           185              1726 2nd Ave
# 1   +12122898226    $$     3.0           315              1735 2nd Ave
# 0   +12127585555    $$     3.5           136            441 Park Ave S
# 0   +12129950242   $$$     3.5          1063            250 Park Ave S
# 0   +12125660006     $     3.5           126            110 Trinity Pl
# 0   +12127550123    $$     3.5           252         807 Lexington Ave
# 1   +12127550123     $     3.0            44         807 Lexington Ave
# 0   +12126885373    $$     3.0            55               8 E 48th St
# 0   +12123692180    $$     4.0           164             150 E 86th St
# 0   +12127854700     $     3.5           662              3 Hanover Sq
# 0   +12127535959   NaN     4.5            34              59 E 59th St
# 1   +12127535959   NaN     4.0             4              59 E 59th St
# 0   +12128580511    $$     4.0           204         483 Amsterdam Ave
# 0   +12128658777     $     4.0            16        1345 Amsterdam Ave
# 0   +12127772188    $$     4.0             6           231 Sullivan St
# 0   +12126775834    $$     4.5           520          400 Lafayette St
# 0   +12129410911    $$     3.5          1472             18 E Broadway
# 0   +16469129061    $$     4.5            93              310 W 4th St
# 0   +12122576434    $$     4.0            58             140 E 45th St
# 0   +12127521495  $$$$     4.0           362               3 E 52nd St
#
#     address2        address3      city zip_code country state  \
# 0                             New York    10014      US    NY
# 1                             New York    10014      US    NY
# 0       None                  New York    10038      US    NY
# 1                             New York    10007      US    NY
# 0                             New York    10030      US    NY
# 0                             New York    10005      US    NY
# 0                             New York    10009      US    NY
# 0                             New York    10009      US    NY
# 0                       None  New York    10014      US    NY
# 0       None                  New York    10128      US    NY
# 0                       None  New York    10013      US    NY
# 1                             New York    10013      US    NY
# 0                       None  New York    10003      US    NY
# 0                             New York    10014      US    NY
# 1                             New York    10014      US    NY
# 0                       None  New York    10075      US    NY
# 0                             New York    10036      US    NY
